# %%
import pandas as pd

# %%
df=pd.read_csv("https://github.com/vistec-AI/WangchanX-Eval/raw/main/SeaLLM-7B-v2.5.csv")

# %%
df
# Out:
#                           id           references  \
# 0   56beb4343aeaaa14008c925b                  308
# 1   56beb4343aeaaa14008c925c                  136
# 2   56beb4343aeaaa14008c925d                  118
# 3   56beb4343aeaaa14008c925e                  สี่
# 4   56beb4343aeaaa14008c925f        คาวันน์ ชอร์ต
# ..                       ...                  ...
# 95  5733834ed058e614000b5c29                  374
# 96  5733834ed058e614000b5c2a  สหพรรคแรงงานโปแลนด์
# 97  56dde1d966d3e219004dad8d                รอลโล
# 98  56de0daecffd8e1900b4b595                โดรโก
# 99  56de0daecffd8e1900b4b596     วิลเลียมแขนเหล็ก
#
#                                               context  \
# 0   ﻿ทีมรับของแพนเธอร์สถอดใจที่คะแนน 308 ได้อันดับ...
# 1   ﻿ทีมรับของแพนเธอร์สถอดใจที่คะแนน 308 ได้อันดับ...
# 2   ﻿ทีมรับของแพนเธอร์สถอดใจที่คะแนน 308 ได้อันดับ...
# 3   ﻿ทีมรับของแพนเธอร์สถอดใจที่คะแนน 308 ได้อันดับ...
# 4   ﻿ทีมรับของแพนเธอร์สถอดใจที่คะแนน 308 ได้อันดับ...
# ..                                                ...
# 95  ตลาดหลักทรัพย์แห่งแรกของวอร์ซอว์ก่อตั้งขึ้นในป...
# 96  ตลาดหลักทรัพย์แห่งแรกของวอร์ซอว์ก่อตั้งขึ้นในป...
# 97  ก่อนการมาถึงของ รอลโล ประชากรของที่นี่ถือว่าเป...
# 98  ครอบครัวชาวนอร์มันที่โดดเด่นที่สุดสองครอบครัวซ...
# 99  ครอบครัวชาวนอร์มันที่โดดเด่นที่สุดสองครอบครัวซ...
#
#                                              question  \
# 0              ทีมรับของแพนเธอร์สยอมแพ้ที่คะแนนเท่าไร
# 1           จาเรด อัลเลน ทำการแซ็คไปกี่ครั้งตลอดอาชีพ
# 2                        ลูค คีคลี แท็คเกิลไปกี่ครั้ง
# 3              จอช นอร์แมน อินเตอร์เซปลูกบอลได้กี่ลูก
# 4           ใครทำการแซ็คได้มากที่สุดของทีมในฤดูกาลนี้
# ..                                                ...
# 95  มีกี่บริษัทที่อยู่ในรายชื่อของตลาดหลักทรัพย์วอ...
# 96  ตลาดหลักทรัพย์วอร์ซอว์ตั้งอยู่ในอดีตสำนักงานให...
# 97  การมาถึงของใครที่ทำให้ผู้ตั้งถิ่นฐานชาวไวกิงมี...
# 98  ผู้นำที่ได้รับมอบบรรดาศักดิ์จากจักรพรรดิอ็องรี...
# 99                              ใครคือเคานต์แห่งเมลฟี
#
#                                           predictions
# 0                ทีมรับของแพนเธอร์สยอมแพ้ที่คะแนน 308
# 1   จาเรด อัลเลน มีสถิตินำจากการแซ็คตลอดอาชีพนักอเ...
# 2                 ลูค คีคลี ทำการแท็คเกิลไป 118 ครั้ง
# 3   วริน นอร์แมนทำการแทรกบอลได้ 4 ครั้ง และ 2 ของต...
# 4   ในบริบทที่ให้มา คาวันน์ ชอต เป็นผู้เล่นตำแหน่ง...
# ..                                                ...
# 95  ในสิงหาคมปี 2009 ตลาดหลักทรัพย์วอร์ซอว์มีบริษั...
# 96  ตลาดหลักทรัพย์วอร์ซอว์ตั้งอยู่ในอดีตสำนักงานให...
# 97  การมาถึงของ รอลโล (Rolleux) ทำให้ผู้ตั้งถิ่นฐา...
# 98                                              โดรโก
# 99  แคทเทอรี่แห่งเมลฟีคือ วิลเลียมแขนเหล็ก (Willia...
#
# [100 rows x 5 columns]

# %%
df.id
# Out:
# 0     56beb4343aeaaa14008c925b
# 1     56beb4343aeaaa14008c925c
# 2     56beb4343aeaaa14008c925d
# 3     56beb4343aeaaa14008c925e
# 4     56beb4343aeaaa14008c925f
#                 ...
# 95    5733834ed058e614000b5c29
# 96    5733834ed058e614000b5c2a
# 97    56dde1d966d3e219004dad8d
# 98    56de0daecffd8e1900b4b595
# 99    56de0daecffd8e1900b4b596
# Name: id, Length: 100, dtype: object

# %%
en_df = pd.read_parquet("hf://datasets/google/xquad/xquad.zh/validation-00000-of-00001.parquet")

# %%
test_en=en_df.loc[en_df['id'].isin(df["id"])]

# %%
test_en
# Out:
#                           id  \
# 0   56beb4343aeaaa14008c925b
# 1   56beb4343aeaaa14008c925c
# 2   56beb4343aeaaa14008c925d
# 3   56beb4343aeaaa14008c925e
# 4   56beb4343aeaaa14008c925f
# ..                       ...
# 95  5733834ed058e614000b5c29
# 96  5733834ed058e614000b5c2a
# 97  56dde1d966d3e219004dad8d
# 98  56de0daecffd8e1900b4b595
# 99  56de0daecffd8e1900b4b596
#
#                                               context  \
# 0   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 1   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 2   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 3   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 4   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# ..                                                ...
# 95  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 96  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 97  在罗洛 大军到来之前，它的人口与皮卡第 (Picardy) 或法兰西岛 (Île-de-Fr...
# 98  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
# 99  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
#
#                              question  \
# 0                        黑豹队的防守丢了多少分？
# 1                    贾里德在职业生涯中有多少次擒杀？
# 2                     卢克·坎克利贡献了多少次擒抱？
# 3                        约什·诺曼拦截了多少球？
# 4                     本赛季谁为球队贡献的擒杀最多？
# ..                                ...
# 95       2009 年 8 月，有多少家公司在华沙证券交易所上市？
# 96  在 2000 年以前，华沙证券交易所所在的大楼是什么组织的前总部？
# 97               谁的到来给了原维京定居者一个共同的身份？
# 98                    亨利三世册封的领袖叫什么名字？
# 99                           谁是梅尔菲伯爵？
#
#                                               answers
# 0             {'text': ['308'], 'answer_start': [10]}
# 1          {'text': ['136 次'], 'answer_start': [162]}
# 2            {'text': ['118'], 'answer_start': [300]}
# 3              {'text': ['四次'], 'answer_start': [53]}
# 4           {'text': ['卡万·肖特'], 'answer_start': [68]}
# ..                                                ...
# 95           {'text': ['374'], 'answer_start': [137]}
# 96       {'text': ['波兰联合工人党'], 'answer_start': [196]}
# 97              {'text': ['罗洛'], 'answer_start': [1]}
# 98    {'text': ['卓戈 (Drogo)'], 'answer_start': [331]}
# 99  {'text': ['铁壁威廉 (William Iron Arm)'], 'answer_...
#
# [100 rows x 4 columns]

# %%
test_en["references"]=[i["text"][0] for i in test_en["answers"]]
# Out:
# /tmp/ipykernel_208222/587633421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_en["references"]=[i["text"][0] for i in test_en["answers"]]

# %%
test_en
# Out:
#                           id  \
# 0   56beb4343aeaaa14008c925b
# 1   56beb4343aeaaa14008c925c
# 2   56beb4343aeaaa14008c925d
# 3   56beb4343aeaaa14008c925e
# 4   56beb4343aeaaa14008c925f
# ..                       ...
# 95  5733834ed058e614000b5c29
# 96  5733834ed058e614000b5c2a
# 97  56dde1d966d3e219004dad8d
# 98  56de0daecffd8e1900b4b595
# 99  56de0daecffd8e1900b4b596
#
#                                               context  \
# 0   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 1   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 2   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 3   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 4   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# ..                                                ...
# 95  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 96  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 97  在罗洛 大军到来之前，它的人口与皮卡第 (Picardy) 或法兰西岛 (Île-de-Fr...
# 98  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
# 99  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
#
#                              question  \
# 0                        黑豹队的防守丢了多少分？
# 1                    贾里德在职业生涯中有多少次擒杀？
# 2                     卢克·坎克利贡献了多少次擒抱？
# 3                        约什·诺曼拦截了多少球？
# 4                     本赛季谁为球队贡献的擒杀最多？
# ..                                ...
# 95       2009 年 8 月，有多少家公司在华沙证券交易所上市？
# 96  在 2000 年以前，华沙证券交易所所在的大楼是什么组织的前总部？
# 97               谁的到来给了原维京定居者一个共同的身份？
# 98                    亨利三世册封的领袖叫什么名字？
# 99                           谁是梅尔菲伯爵？
#
#                                               answers               references
# 0             {'text': ['308'], 'answer_start': [10]}                      308
# 1          {'text': ['136 次'], 'answer_start': [162]}                    136 次
# 2            {'text': ['118'], 'answer_start': [300]}                      118
# 3              {'text': ['四次'], 'answer_start': [53]}                       四次
# 4           {'text': ['卡万·肖特'], 'answer_start': [68]}                    卡万·肖特
# ..                                                ...                      ...
# 95           {'text': ['374'], 'answer_start': [137]}                      374
# 96       {'text': ['波兰联合工人党'], 'answer_start': [196]}                  波兰联合工人党
# 97              {'text': ['罗洛'], 'answer_start': [1]}                       罗洛
# 98    {'text': ['卓戈 (Drogo)'], 'answer_start': [331]}               卓戈 (Drogo)
# 99  {'text': ['铁壁威廉 (William Iron Arm)'], 'answer_...  铁壁威廉 (William Iron Arm)
#
# [100 rows x 5 columns]

# %%
del test_en["answers"]

# %%
test_en
# Out:
#                           id  \
# 0   56beb4343aeaaa14008c925b
# 1   56beb4343aeaaa14008c925c
# 2   56beb4343aeaaa14008c925d
# 3   56beb4343aeaaa14008c925e
# 4   56beb4343aeaaa14008c925f
# ..                       ...
# 95  5733834ed058e614000b5c29
# 96  5733834ed058e614000b5c2a
# 97  56dde1d966d3e219004dad8d
# 98  56de0daecffd8e1900b4b595
# 99  56de0daecffd8e1900b4b596
#
#                                               context  \
# 0   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 1   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 2   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 3   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# 4   黑豹队的防守只丢了 308分，在联赛中排名第六，同时也以 24 次拦截领先国家橄榄球联盟 (...
# ..                                                ...
# 95  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 96  华沙的第一家证券交易所成立于 1817 年，一直营业到第二次世界大战。1991 年 4 月，...
# 97  在罗洛 大军到来之前，它的人口与皮卡第 (Picardy) 或法兰西岛 (Île-de-Fr...
# 98  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
# 99  欧特维尔的坦克雷德 (Tancred of Hauteville) 和德伦戈特 (Dreng...
#
#                              question               references
# 0                        黑豹队的防守丢了多少分？                      308
# 1                    贾里德在职业生涯中有多少次擒杀？                    136 次
# 2                     卢克·坎克利贡献了多少次擒抱？                      118
# 3                        约什·诺曼拦截了多少球？                       四次
# 4                     本赛季谁为球队贡献的擒杀最多？                    卡万·肖特
# ..                                ...                      ...
# 95       2009 年 8 月，有多少家公司在华沙证券交易所上市？                      374
# 96  在 2000 年以前，华沙证券交易所所在的大楼是什么组织的前总部？                  波兰联合工人党
# 97               谁的到来给了原维京定居者一个共同的身份？                       罗洛
# 98                    亨利三世册封的领袖叫什么名字？               卓戈 (Drogo)
# 99                           谁是梅尔菲伯爵？  铁壁威廉 (William Iron Arm)
#
# [100 rows x 4 columns]

# %%
test_en.to_csv("eval.csv",index=False)
